# %% [markdown]
# <a href="https://colab.research.google.com/github/jayanthoffl/fake-news--prediction/blob/main/news_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
true = pd.read_csv('True.csv')
fake = pd.read_csv('Fake.csv')

# %%
true['label'] = 1
fake['label'] = 0

# %%
news = pd.concat([true, fake], ignore_index=True)

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news = news.drop(['title','subject','date'], axis =1)

# %%
news = news.sample(frac = 1)

# %%
news.head()
# Out:
#                                                     text  label
# 21371  AL UDEID AIR BASE, Qatar (Reuters) - Even as t...      1
# 32107  This unbelievable story of unbridled censorshi...      0
# 27482  One of America s most legendary journalists, D...      0
# 18367  BERLIN (Reuters) - It is important for Spain t...      1
# 34566  Fans of #CrookedHillary are not going to like ...      0

# %%
news.reset_index(inplace = True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0  21371  AL UDEID AIR BASE, Qatar (Reuters) - Even as t...      1
# 1  32107  This unbelievable story of unbridled censorshi...      0
# 2  27482  One of America s most legendary journalists, D...      0
# 3  18367  BERLIN (Reuters) - It is important for Spain t...      1
# 4  34566  Fans of #CrookedHillary are not going to like ...      0

# %%
news = news.drop(['index'], axis = 1)

# %%
import re

def wordopt(text):
  text = text.lower()

  text = re.sub(r'https?://\S+|www\.\S+','',text)

  text = re.sub(r'<.*?>','',text)
  text = re.sub(r'\d','',text)
  text = re.sub(r'[^\w\s]','',text)
  text = re.sub(r'\n','',text)

  return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        al udeid air base qatar reuters  even as tensi...
# 1        this unbelievable story of unbridled censorshi...
# 2        one of america s most legendary journalists da...
# 3        berlin reuters  it is important for spain to u...
# 4        fans of crookedhillary are not going to like t...
#                                ...
# 44893    west palm beach flawashington reuters  us pres...
# 44894    washington reuters  bernie sanders highflying ...
# 44895    the  presidential election continues to defy e...
# 44896     a source close to anthony weiner s legal team...
# 44897    reuters  bluntspoken janet reno who served eig...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']
y = news['label']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,stratify = y)

# %%
vectorizer = TfidfVectorizer()
xv_train = vectorizer.fit(x_train)

# %%
xv_train = vectorizer.transform(x_train)

# %%
xv_test = vectorizer.transform(x_test)
xv_test = vectorizer.transform(x_test)

# %%
LD = LogisticRegression()
LD.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
X_train_prediction = LD.predict(xv_train)
training_data_accuracy = accuracy_score(X_train_prediction, y_train)

# %%
print("Accuracy of training is :" , training_data_accuracy)
# Out:
# Accuracy of training is : 0.992140766195749

# %%
from sklearn.tree import DecisionTreeClassifier

DTC = DecisionTreeClassifier()

# %%
DTC.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = DTC.predict(xv_test)

# %%
DTC.score(xv_test, y_test)
# Out:
# 0.9953971789161099

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7045
#            1       1.00      1.00      1.00      6425
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
from sklearn.ensemble import RandomForestClassifier
RFC = RandomForestClassifier()
RFC.fit(xv_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predict_rfc = RFC.predict(xv_test)

# %%
RFC.score(xv_test, y_test)
# Out:
# 0.988641425389755

# %%
print(classification_report(y_test,predict_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7045
#            1       0.99      0.99      0.99      6425
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.ensemble import GradientBoostingClassifier
GBC = GradientBoostingClassifier()
GBC.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred_GBC = GBC.predict(xv_test)

# %%
GBC.score(xv_test, y_test)
# Out:
# 0.9947290274684484

# %%
print(classification_report(y_test, pred_GBC))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      7045
#            1       0.99      1.00      0.99      6425
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
def output_label(n):
  if n == 0:
    return "It is a Fake News"
  elif n == 1:
    return "It is a True News"

# %%
def manual_testing(news):
  testing_news = {"text": [news]}
  new_def_test = pd.DataFrame(testing_news)
  new_def_test["text"] = new_def_test['text'].apply(wordopt)
  new_x_test = new_def_test["text"]
  new_xv_test = vectorizer.transform(new_x_test)
  pred_LD = LD.predict(new_xv_test)
  pred_GBC = GBC.predict(new_xv_test)
  predict_rfc = RFC.predict(new_xv_test)

  return "\n\nLinear Regression Prediction: {} \nGradientBoostClassifier Prediction: {} \nRandomForestClassifier Prediction: {}".format(output_label(pred_LD[0]),
                                                                                  output_label(pred_GBC[0]),
                                                                                  output_label(predict_rfc[0]))

# %%
while True:
    news_article = input("Enter a news article (or type 'exit' to quit): ")
    if news_article.lower() == 'exit':
        print("Exiting the program.")
        break

    print(manual_testing(news_article))
# Out:
# Enter a news article (or type 'exit' to quit): 42-year-old man was killed by his friend for allegedly spre ..  Read more at: http://timesofindia.indiatimes.com/articleshow/107788768.cms?utm_source=contentofinterest&utm_medium=text&utm_campaign=cppst
#
#
# Linear Regression Prediction: It is a Fake News
# GradientBoostClassifier Prediction: It is a Fake News
# RandomForestClassifier Prediction: It is a Fake News
# Enter a news article (or type 'exit' to quit): exit
# Exiting the program.

# %%
# Out:
# '\n\nLR Prediction: It is a Fake News \nGBC Prediction: It is a Fake News \nRFC Prediction: It is a Fake News'
